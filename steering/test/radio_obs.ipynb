# %%
import aim_resolve as aim
import resolve as rve
import numpy as np
# Out:
# jwst not installed. Some JWST functions will not work.
# shapely not installed. Some JWST functions will not work.
# Could not import MPI

# %%
obs_dir = '/scratch/users/rfuchs/data/eso_data_from_oleg.npz'
obs0 = rve.Observation.load(obs_dir)
print(obs0)
# Out:
# Observation:
#   Source name:		ESO137-001
#   Visibilities shape:	(4, 4598424, 931)
#   # visibilities:	17124530976
#   Frequency range:	879.720 -- 1657.978 MHz
#   Polarizations:	XX, XY, YX, YY
#   Shortest baseline:	29.3 m -> 0.667 deg
#   Longest baseline:	7697.6 m -> 4.845 arcsec
#   Flagged:		36.3%

# %%
obs0_i = obs0.restrict_to_stokesi()
obs0_i = obs0_i.average_stokesi()
print(obs0_i)
# Out:
# Observation:
#   Source name:		ESO137-001
#   Visibilities shape:	(1, 4598424, 931)
#   # visibilities:	4281132744
#   Frequency range:	879.720 -- 1657.978 MHz
#   Polarizations:	I
#   Shortest baseline:	29.3 m -> 0.667 deg
#   Longest baseline:	7697.6 m -> 4.845 arcsec
#   Flagged:		36.3%

# %%
obs0_a, idx_a = obs0_i.restrict_by_freq(961e6, 1145e6, True)
print('index_a:', idx_a)
print(obs0_a)
# obs0_a.save('/scratch/users/rfuchs/data/eso_961-1145mhz.npz', False)
# Out:
# index_a: slice(np.int64(98), np.int64(318), None)
# Observation:
#   Source name:		ESO137-001
#   Visibilities shape:	(1, 4598424, 220)
#   # visibilities:	1011653280
#   Frequency range:	961.642 -- 1144.712 MHz
#   Polarizations:	I
#   Shortest baseline:	29.3 m -> 0.611 deg
#   Longest baseline:	7697.6 m -> 7.018 arcsec
#   Flagged:		14.3%

# %%
obs0_b, idx_b = obs0_i.restrict_by_freq(1295e6, 1503e6, True)
print('index_b:', idx_b)
print(obs0_b)
# obs0_b.save('/scratch/users/rfuchs/data/eso_1295-1503mhz.npz', False)
# Out:
# index_b: slice(np.int64(497), np.int64(745), None)
# Observation:
#   Source name:		ESO137-001
#   Visibilities shape:	(1, 4598424, 248)
#   # visibilities:	1140409152
#   Frequency range:	1295.181 -- 1502.493 MHz
#   Polarizations:	I
#   Shortest baseline:	29.3 m -> 0.453 deg
#   Longest baseline:	7697.6 m -> 5.347 arcsec
#   Flagged:		13.0%

# %%
idx_c = [i for s in (idx_a, idx_b) for i in range(s.start, s.stop)]
print('index_c:', idx_c)

obs0_c = obs0_i.get_freqs(idx_c)
print(obs0_c)
obs0_c.save('/scratch/users/rfuchs/data/eso_961-1503mhz.npz', False)
# Out:
# index_c: [98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 497, 498, 499, 500, 501, 502, 503, 504, 505, 506, 507, 508, 509, 510, 511, 512, 513, 514, 515, 516, 517, 518, 519, 520, 521, 522, 523, 524, 525, 526, 527, 528, 529, 530, 531, 532, 533, 534, 535, 536, 537, 538, 539, 540, 541, 542, 543, 544, 545, 546, 547, 548, 549, 550, 551, 552, 553, 554, 555, 556, 557, 558, 559, 560, 561, 562, 563, 564, 565, 566, 567, 568, 569, 570, 571, 572, 573, 574, 575, 576, 577, 578, 579, 580, 581, 582, 583, 584, 585, 586, 587, 588, 589, 590, 591, 592, 593, 594, 595, 596, 597, 598, 599, 600, 601, 602, 603, 604, 605, 606, 607, 608, 609, 610, 611, 612, 613, 614, 615, 616, 617, 618, 619, 620, 621, 622, 623, 624, 625, 626, 627, 628, 629, 630, 631, 632, 633, 634, 635, 636, 637, 638, 639, 640, 641, 642, 643, 644, 645, 646, 647, 648, 649, 650, 651, 652, 653, 654, 655, 656, 657, 658, 659, 660, 661, 662, 663, 664, 665, 666, 667, 668, 669, 670, 671, 672, 673, 674, 675, 676, 677, 678, 679, 680, 681, 682, 683, 684, 685, 686, 687, 688, 689, 690, 691, 692, 693, 694, 695, 696, 697, 698, 699, 700, 701, 702, 703, 704, 705, 706, 707, 708, 709, 710, 711, 712, 713, 714, 715, 716, 717, 718, 719, 720, 721, 722, 723, 724, 725, 726, 727, 728, 729, 730, 731, 732, 733, 734, 735, 736, 737, 738, 739, 740, 741, 742, 743, 744]
# Observation:
#   Source name:		ESO137-001
#   Visibilities shape:	(1, 4598424, 468)
#   # visibilities:	2152062432
#   Frequency range:	961.642 -- 1502.493 MHz
#   Polarizations:	I
#   Shortest baseline:	29.3 m -> 0.611 deg
#   Longest baseline:	7697.6 m -> 5.347 arcsec
#   Flagged:		13.6%

# %%
obs_dir = '/scratch/users/rfuchs/data/eso_961-1145mhz.npz'
obs0 = rve.Observation.load(obs_dir)
print(obs0)
# Out:
# Observation:
#   Source name:		ESO137-001
#   Visibilities shape:	(1, 4598424, 220)
#   # visibilities:	1011653280
#   Frequency range:	961.642 -- 1144.712 MHz
#   Polarizations:	I
#   Shortest baseline:	29.3 m -> 0.611 deg
#   Longest baseline:	7697.6 m -> 7.018 arcsec
#   Flagged:		14.3%

# %%
freq_a = [float(s.mean()) for s in np.array_split(obs0.freq, 3)]
idx_a = [len(s) for s in np.array_split(obs0.freq, 3)]
print('freq_a:', freq_a)
print('idx_a:', idx_a)
obs1 = obs0.get_freqs(range(74, 74+73))
print(obs1)
# Out:
# freq_a: [992153320.3125, 1053594726.5625, 1114618164.0625]
# idx_a: [74, 73, 73]
# Observation:
#   Source name:		ESO137-001
#   Visibilities shape:	(1, 4598424, 73)
#   # visibilities:	335684952
#   Frequency range:	1023.501 -- 1083.688 MHz
#   Polarizations:	I
#   Shortest baseline:	29.3 m -> 0.574 deg
#   Longest baseline:	7697.6 m -> 7.413 arcsec
#   Flagged:		14.9%

# %%
print(obs1.freq.mean())
obs1.save('/scratch/users/rfuchs/data/eso_1024-1084mhz.npz', False)
# Out:
# 1053594726.5625

# %%
obs_dir = '/scratch/users/rfuchs/data/eso_961-1503mhz.npz'

obs1 = aim.radio_data(fname=obs_dir)
freq = obs1.freq

# %%
freq_a = freq[(freq < 1200e6)]
freq_b = freq[(freq >= 1200e6)]

freq_a = [float(s.mean()) for s in np.array_split(freq_a, 3)]
print('freq_a:', freq_a)
freq_b = [float(s.mean()) for s in np.array_split(freq_b, 3)]
print('freq_b:', freq_b)

freq = freq_a + freq_b
print('freq:', freq)
# Out:
# freq_a: [992153320.3125, 1053594726.5625, 1114618164.0625]
# freq_b: [1329454101.5625, 1398998058.6408134, 1468637695.3125]
# freq: [992153320.3125, 1053594726.5625, 1114618164.0625, 1329454101.5625, 1398998058.6408134, 1468637695.3125]
# Der Kernel ist beim Ausführen von Code in der aktuellen Zelle oder einer vorherigen Zelle abgestürzt.
#
# Bitte überprüfen Sie den Code in der/den Zelle(n), um eine mögliche Fehlerursache zu identifizieren.
#
# Klicken Sie <a href='https://aka.ms/vscodeJupyterKernelCrash'>hier</a>, um weitere Informationen zu erhalten.
#
# Weitere Informationen finden Sie unter Jupyter <a href='command:jupyter.viewOutput'>Protokoll</a>.

# %%
obs_dir = '/Users/rf/Development/data/eso_986-1137mhz.npz'

obs1 = aim.radio_data(fname=obs_dir)
freq = obs1.freq

for f in freq:
    print(f)

print([float(freq[:4].mean()), float(freq[4:].mean())])
print(freq.mean())
# Out:
# 986719726.5625
# 1011797851.5625
# 1036875976.5625
# 1061954101.5625
# 1087032226.5625
# 1112110351.5625
# 1137188476.5625
# [1024336914.0625, 1112110351.5625]
# 1061954101.5625

# %%
obs_dir = '/Users/rf/Development/data/eso_1356-1439mhz.npz'

obs2 = aim.radio_data(fname=obs_dir)
freq = obs2.freq

for f in freq:
    print(f)

print([float(freq[:4].mean()), float(freq[4:].mean())])
# Out:
# 1356204101.5625
# 1367907226.5625
# 1379610351.5625
# 1391313476.5625
# 1403016601.5625
# 1414719726.5625
# 1427258789.0625
# 1438961914.0625
# [1373758789.0625, 1420989257.8125]
